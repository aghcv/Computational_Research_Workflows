# %% [markdown]
# # Session 5: Running a Real Research Repository
#
# **Workshop:** Undergraduate Research Computing Bootcamp
#
# > Open this notebook in Google Colab and run each code cell in order.

# %% [markdown]
# ## Learning objectives
#
# - Clone a real repository
# - Install dependencies
# - Run example scripts or notebooks
# - Modify parameters and inspect outputs

# %% [markdown]
# ## How to use this notebook
#
# 1. Read each short explanation.
# 2. Run each code cell.
# 3. Complete the exercises marked **Your turn**.
# 4. Save a copy of the notebook to your Google Drive or GitHub.

# %% [markdown]
# ## Goal
#
# This session transitions from toy examples to real research code.
#
# Replace the placeholder repository URL with your actual lab or workshop repository.

# %%
REPO_URL = "https://github.com/YOUR-ORG/YOUR-REPOSITORY.git"
REPO_NAME = REPO_URL.split("/")[-1].replace(".git", "")

print("Repository:", REPO_URL)
print("Folder name:", REPO_NAME)

# %%
# Uncomment after replacing REPO_URL
# !git clone {REPO_URL}
# %cd {REPO_NAME}
# !ls

# %% [markdown]
# ## Install dependencies
#
# Most Python repositories include one of these:
#
# - `requirements.txt`
# - `environment.yml`
# - `pyproject.toml`
#
# For Colab, `requirements.txt` is usually the simplest.

# %%
# Example:
# !pip install -r requirements.txt

# %% [markdown]
# ## Explore the repository
#
# Students should identify:
#
# - Where is the README?
# - Where are examples?
# - Where is the source code?
# - Where are tests?
# - What command runs the demo?

# %%
# Useful commands after cloning:
# !find . -maxdepth 2 -type f | sort | head -50
# !cat README.md

# %% [markdown]
# ## Your turn
#
# Run one example from the repository. Then change one input parameter and describe how the output changed.

# %% [markdown]
# ## Wrap-up
#
# Before the next session, make sure you can explain the key terms from this notebook in your own words and repeat the hands-on exercise without copying every command.
